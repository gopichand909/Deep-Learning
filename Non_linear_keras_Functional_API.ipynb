# %% [markdown]
# <a href="https://colab.research.google.com/github/gopichand909/Deep-Learning/blob/main/Non_linear_keras_Functional_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
